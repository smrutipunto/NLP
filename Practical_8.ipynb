# %% [markdown]
# <a href="https://colab.research.google.com/github/smrutipunto/NLP/blob/main/Practical_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Named Entity Recognition

# %%
pip install flair
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 14.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.5/776.5 kB 26.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.6/202.6 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 38.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.6/82.6 kB 3.5 MB/s eta 0:00:00
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=005aa7eda4b795adc3e18ef1f9b748c9a36f7a56f217feffe22fcf7d20320ce7
# ...

# %%
from flair.models import SequenceTagger
from flair.data import Sentence


# I am Abhinav I live in Goa
# Abhinav = Person, Goa Place/Location


def get_user_input():
    # Step 2: Text Input
    user_input = input("Please enter a text: ")
    return user_input

def named_entity_recognition(text):
    # Step 3: NER Implementation
    # Load the pre-trained NER model
    tagger = SequenceTagger.load("ner")

    # Create a Sentence object
    sentence = Sentence(text)

    # Predict entities
    tagger.predict(sentence)

    return sentence

def print_named_entities(sentence):
    # Step 4: User-Friendly Output
    print("\nNamed Entities:")
    for entity in sentence.get_spans('ner'):
        print(f"- {entity.text} ({entity.tag})")

# Main execution
if __name__ == "__main__":
    text = get_user_input()  # Get text input from user
    sentence = named_entity_recognition(text)  # Perform NER
    print_named_entities(sentence)  # Print results
#Barack Obama was the 44th President of the United States.
#The Eiffel Tower is one of the most famous landmarks in Paris, France.
#Apple Inc. announced a new product launch in San Francisco.

# ORG ORGANISATION
# LOC LOCATION
# Out:
# Please enter a text: Apple Inc. announced a new product launch in San Francisco.
# 2024-10-22 13:54:46,178 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
#
# Named Entities:
# - Apple Inc (ORG)
# - San Francisco (LOC)
